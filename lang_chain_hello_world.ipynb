# %% [markdown]
# <a href="https://colab.research.google.com/github/malaika-kaleem1605/Test-project-of-PIAIC/blob/main/lang_chain_hello_world.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install langchain_google_genai
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.3/41.3 kB 4.0 MB/s eta 0:00:00
# ...

# %%
import langchain_google_genai as genai

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

# %%
# !pip install google-generativeai

# %%
from google.colab import userdata
userdata.get('GOOGLE_API_KEY')
# Out:
# 'AIzaSyDp_SIE8CEgw2I0cS5W4P2Ch6n0NvH3ltA'

# %%
model : ChatGoogleGenerativeAI = ChatGoogleGenerativeAI(
    model="gemini-1.5-flash",
    api_key='AIzaSyDp_SIE8CEgw2I0cS5W4P2Ch6n0NvH3ltA',

)

# %%
response  = model.invoke("who is the founder of pakistan?")

# %%
print(response.content)
# Out:
# Muhammad Ali Jinnah is considered the founder of Pakistan.
